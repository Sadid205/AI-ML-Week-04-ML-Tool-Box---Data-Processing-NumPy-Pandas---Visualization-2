# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
student = pd.read_csv("sns_data (1).csv")
student.head()
# Out:
#    student_id class_level   subject  study_hours  test_score  week  \
# 0           1    Freshman      Math            5          78     1
# 1           2    Freshman   Science            3          65     1
# 2           3    Freshman   History            4          70     1
# 3           4    Freshman  Language            2          60     1
# 4           5   Sophomore      Math            6          82     1
#
#    attendance_rate  gender  hostel  Tshirt_size
# 0               90    Male    True           30
# 1               80  Female   False           20
# 2               85    Male    True           20
# 3               75  Female    True           40
# 4               92    Male    True           20

# %%
# Lineplot using Seaborn 
# axes level
sns.lineplot(data=student,x='week',y='attendance_rate',errorbar=None)
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
sns.lineplot(data=student,x='week',y='attendance_rate',errorbar=None,hue='gender')
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
# Figure level
sns.relplot(kind='line',data=student,x='week',y='attendance_rate',errorbar=None,hue='gender')

# %%
sns.relplot(kind='line',data=student,x='week',y='test_score',errorbar=None,hue='gender')

# %%
sns.relplot(kind='line',data=student,x='week',y='test_score',errorbar=None,hue='class_level')

# %%
sns.relplot(kind='line',data=student,x='week',y='attendance_rate',errorbar=None,hue='class_level')

# %%
# Scatter Plot Using seaborn
sns.scatterplot(data=student,x='study_hours',y='test_score')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.scatterplot(data=student,x='study_hours',y='test_score',hue='gender',style='subject',size='Tshirt_size')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.relplot(kind='scatter',data=student,x='study_hours',y='test_score',hue='gender',style='subject',size='Tshirt_size')

# %%
tips_data = sns.load_dataset("tips")
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(kind='scatter',data=tips_data,x='total_bill',y='tip',hue='sex',style='time',size='size')

# %%
student = pd.read_csv("student_dataset_complete.csv")
student
# Out:
#     number_courses  time_study   Marks  student_id  class_level  subject  \
# 0                3       4.508  19.202           1           10  Science
# 1                4       0.096   7.734           2           12     Math
# 2                4       3.133  13.811           3           11  Science
# 3                6       7.909  53.018           4           10  Science
# 4                8       7.811  55.299           5           11  English
# ..             ...         ...     ...         ...          ...      ...
# 95               6       3.561  19.128          96           11  English
# 96               3       0.301   5.609          97           10  Science
# 97               4       7.163  41.444          98           11     Math
# 98               7       0.309  12.027          99           12     Math
# 99               3       6.335  32.357         100           12  Science
#
#     study_hours  test_score  week  attendance_rate gender  hostel  \
# ...

# %%
# Facet Plot

sns.scatterplot(data=student,x='study_hours',y='test_score',hue='gender')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.relplot(data=student,x='study_hours',y='test_score',hue='gender')

# %%
sns.relplot(data=student,x='study_hours',y='test_score',col='gender')

# %%
sns.relplot(data=student,x='study_hours',y='test_score',col='gender',row='hostel')

# %%
sns.relplot(kind='scatter',data=student,x='study_hours',y='test_score',col='week',col_wrap=2)

# %%
# Histogram using seaborn
# axes level 
sns.histplot(data=student,x='attendance_rate',hue='gender',bins=15,element='step')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Count'>

# %%
# figure level
sns.displot(data=student, x='attendance_rate', kind="hist")
# sns.displot(data=student, x='attendance_rate', kind="hist", kde=True)

# %%
sns.displot(data=student, x='attendance_rate', kind="hist",col="gender")

# %%
sns.displot(data=student, x='study_hours', kind="hist",col="gender")

# %%
tips_data = sns.load_dataset("tips")
tips_data.head()
# sns.displot(data=tips_data, x='total_bill',bins=20)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=tips_data, x='tip',bins=20)

# %%
# KDE Plot using seaborn
sns.kdeplot(data=student,x='attendance_rate')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Density'>

# %%
sns.kdeplot(data=tips_data, x='tip',hue='sex',fill=True)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
#  CountPlot 
sns.countplot(data=student,x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=student,x='subject',hue='gender')
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
# Bar Plot
sns.barplot(data=student,x='gender',y='Marks',errorbar=None) # Mean
# Out:
# <Axes: xlabel='gender', ylabel='Marks'>

# %%
sns.barplot(data=student,x='gender',y='Marks',errorbar=None,estimator=np.median) # median
# Out:
# <Axes: xlabel='gender', ylabel='Marks'>

# %%
sns.barplot(data=student,x='gender',y='Marks',errorbar=None,estimator=np.max) # max
# Out:
# <Axes: xlabel='gender', ylabel='Marks'>

# %%
# Regplot and Implot 
# Axes Level
sns.regplot(data=student,x='study_hours',y='test_score')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
# Figure Level 
sns.lmplot(data=student,x='study_hours',y='test_score',hue='gender')

# %%
# Pairplot 
students_marks=student[['Marks','study_hours','attendance_rate','gender']]
students_marks
# Out:
#      Marks  study_hours  attendance_rate gender
# 0   19.202        4.508             0.89      F
# 1    7.734        0.096             0.98      M
# 2   13.811        3.133             0.83      F
# 3   53.018        7.909             0.92      F
# 4   55.299        7.811             0.80      M
# ..     ...          ...              ...    ...
# 95  19.128        3.561             0.94      F
# 96   5.609        0.301             0.83      M
# 97  41.444        7.163             0.97      M
# 98  12.027        0.309             0.98      F
# 99  32.357        6.335             0.95      M
#
# [100 rows x 4 columns]

# %%
sns.pairplot(students_marks)

# %%
sns.pairplot(students_marks,kind='hist')

# %%
sns.pairplot(students_marks,hue='gender')

# %%
 # Join Plot 
sns.jointplot(data=students_marks,x='study_hours',y='Marks')

# %%
sns.jointplot(data=students_marks,x='study_hours',y='Marks',kind='kde')

# %%
sns.jointplot(data=students_marks,x='study_hours',y='Marks',hue='gender')

# %%
# Scatter plot with plotly
fig = px.scatter(student,x='time_study',y='Marks',color='gender',size='Tshirt_size',hover_data=[
    'time_study','Marks','hostel'
])
fig.show()

# %%
# Line plot using plotly
enrolment = pd.read_csv("enrollment_data.csv")
fig = px.line(enrolment,x='Year',y='Programming',markers=True)
fig.show()

# %%
fig = px.line(enrolment,x='Year',y='Digital Marketing',markers=True)
fig.show()

# %%
fig.write_html('digital_marketing_data.html')

# %%
# Histogram using plotly
students_marks
# Out:
#      Marks  study_hours  attendance_rate gender
# 0   19.202        4.508             0.89      F
# 1    7.734        0.096             0.98      M
# 2   13.811        3.133             0.83      F
# 3   53.018        7.909             0.92      F
# 4   55.299        7.811             0.80      M
# ..     ...          ...              ...    ...
# 95  19.128        3.561             0.94      F
# 96   5.609        0.301             0.83      M
# 97  41.444        7.163             0.97      M
# 98  12.027        0.309             0.98      F
# 99  32.357        6.335             0.95      M
#
# [100 rows x 4 columns]

# %%
fig = px.histogram(students_marks,x='attendance_rate')
fig.show()

# %%
fig = px.histogram(students_marks,x='attendance_rate',color='gender',nbins=5)
fig.show()

# %%
# Practice 

df = pd.read_csv("student_IQdata.csv")
df
# Out:
#     Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0        13.5         2.0            17.7        72
# 1         8.0        18.0             5.0        75
# 2         6.4         7.2            22.7        78
# 3         6.9         8.7             6.6       110
# 4        10.5         8.6             5.8       104
# 5         6.8         4.8            18.1        76
# 6         5.5         7.9            24.3        80
# 7         9.6        12.6            15.7       109
# 8         9.1         5.6            24.3        73
# 9         6.7        14.6            13.1       110
# 10        9.7        14.2            20.9        98
# 11       10.4        13.7            14.0       109
# 12        7.7        11.9            23.2        95
# 13       12.5         8.3            13.3        95
# 14        7.6         9.4            16.8        95
# 15       11.4         4.6             7.9        96
# 16        5.6        12.2            12.9       107
# ...

# %%
# Create a scatter plot with Study_Hours on the X-axis and IQ on the Y-axis with seaborn
sns.scatterplot(data=df,x='Study_Hour',y='IQ_Score')
# Out:
# <Axes: xlabel='Study_Hour', ylabel='IQ_Score'>

# %%
# Create a scatter plot with Shoe_Size on the X-Axis and Study_Hours on the Y-axis with seabron
sns.scatterplot(data=df,x='Shoe_Size',y='Study_Hour')
# Out:
# <Axes: xlabel='Shoe_Size', ylabel='Study_Hour'>

# %%
# Create a histogram of Shoe_Size using plotly
fig = px.histogram(df,x='Shoe_Size')
fig.show()

# After you plot it, answer the question: Does there appear to be a correlation?
# Ans : Yes , It has negetive correlation between shoe_size and it's counts
